# %% [markdown]
# <a href="https://colab.research.google.com/github/RKayyy/DBMS_project/blob/main/ML_assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import io

df = pd.read_csv("AWCustomers.csv")

# %%
df.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
drop_columns=  ['Title', 'FirstName', 'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2', 'City', 'StateProvinceName', 'NumberCarsOwned', 'LastUpdated', 'CountryRegionName', 'PostalCode', 'PhoneNumber', 'BirthDate']

# %%
dt = df.drop(drop_columns, axis=1)

# %%
data = dt[:100]

# %%
data
# Out:
#     CustomerID            Education      Occupation Gender MaritalStatus  \
# 0        21173            Bachelors        Clerical      M             M
# 1        13249      Partial College        Clerical      M             M
# 2        29350            Bachelors        Clerical      F             S
# 3        13503      Partial College  Skilled Manual      M             M
# 4        22803      Partial College  Skilled Manual      M             S
# ..         ...                  ...             ...    ...           ...
# 95       11345      Partial College      Management      F             S
# 96       22539  Partial High School  Skilled Manual      M             S
# 97       26226      Partial College      Management      F             M
# 98       22654          High School          Manual      M             S
# 99       20389      Graduate Degree        Clerical      M             M
#
#     HomeOwnerFlag  NumberChildrenAtHome  TotalChildren  YearlyIncome
# ...

# %%
# CustomerID: discrete
# Gender: nominal
# Age: ratio
# MaritalStatus: nominal
# EducationLevel: nominal
# Occupation: nominal
# Income: ratio
# HomeOwnershipFlag: nominal
# NumberofChildren: discrete
# TotalPurchaseValue: ratio

# %%
#Handle Null values

# %%
df['YearlyIncome'].fillna(df['YearlyIncome'].mean(), inplace=True)

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)

# %%
df['MaritalStatus'].fillna(df['MaritalStatus'].mode()[0], inplace=True)

# %%
df['Education'].fillna(df['Education'].mode()[0], inplace=True)
df['Occupation'].fillna(df['Occupation'].mode()[0], inplace=True)

# %%
df['NumberChildrenAtHome'].fillna(0, inplace=True)

# %%
df['TotalChildren'].fillna(0, inplace=True)

# %%
df['HomeOwnerFlag'].fillna(df['HomeOwnerFlag'].mode()[0], inplace=True)

# %%
df.Occupation.any()
# Out:
# True

# %%
df.YearlyIncome.any()
# Out:
# True

# %%
null_count = df['YearlyIncome'].isnull().sum()
null_count
# Out:
# 0

# %%
#Normalisation

# %%
from sklearn.preprocessing import MinMaxScaler
